# %% [markdown]
# ***Project 2 :- ***
#
# *House Price Prediction*
# -------------------------------------------

# %% [markdown]
# **Procedure ↘**
# -     Let's understand what is out problem state.The project aims at building a model of housing prices to predict median house values in Darbhanga using the provided dataset. This model should learn from the data and be able to predict the median housing price in area, given all the metrics.
# -     We will predict price of house on given scenerios, based on something like income of person, the age of the house , the number of rooms are available and what is the actual population of the area.
# -     We will use feature engineering i mean we have latitude and longitude but these are only numbers we cannot predict which city or which area i mean we cannot predict anything , for that we have multiple python libraries that helps us to predict where exactly this latitude and longitude. So we're going to use feature engineering to predict the new data and apart from this we predict various prices.
#
#
# **Workflow** ↘
# -   Data ->>> Training & Testing Dataset ->>> Algorithm ->>> Evaluation ->>> Model ->>> Prediction and Production Data
#
# **Tools And Frameworks** ↘
# - Python
# - Scikit Learn
# - matplotlib
# - Pandas
# - Seaborn
# - Numpy
# - Google Colab

# %% [markdown]
# ---------------------------------------------

# %%
# importing the dependencies 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

# %%
# data = fetch_california_housing()

# %%
# print(data)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
# df = pd.DataFrame

# %%
# data.data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
# data.data.shape
# Out:
# (20640, 8)

# %%
# df = pd.DataFrame(data = data.data)
# df.head()
# Out:
#         0     1         2         3       4         5      6       7
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25

# %% [markdown]
# Articles to Write :-
# - House is a guest room
# - The nerves sense to wrong word
